# %% [markdown]
# ### 简单调用

# %%
import requests
import json
import pprint

# %% [markdown]
# #### 搜索POI
# https://lbs.amap.com/api/webservice/guide/api/search/

# %%
url = 'https://restapi.amap.com/v3/place/text?types=050000&city=长沙&offset=20&page=1&key=9c9dd3c0a50d3a9c3dc905244785ee9c'

res = requests.get(url)
print(res.text)
# Out:
# {"status":"1","count":"893","info":"OK","infocode":"10000","suggestion":{"keywords":[],"cities":[]},"pois":[{"id":"B0FFGA6OV1","parent":[],"childtype":[],"name":"唐老鸭农庄","type":"餐饮服务;中餐厅;中餐厅","typecode":"050100","biz_type":"diner","address":"中岳村浏东公路","location":"113.991255,28.459114","tel":"18874731138","distance":[],"biz_ext":{"rating":"4.5","cost":[],"meal_ordering":"0"},"pname":"湖南省","cityname":"长沙市","adname":"浏阳市","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/6bc2efbea43d80030f2e535dc40ccad1","title":[],"provider":[]},{"url":"http://store.is.autonavi.com/showpic/e5f0100a7adf360fdb808f6fb4f355ff","title":[],"provider":[]},{"url":"http://store.is.autonavi.com/showpic/83fd785681f634fb7836d65cab2ef420","title":[],"provider":[]}]},{"id":"B02DB0TUOP","parent":[],"childtype":[],"name":"七碗茶(状元洲路)","type":"购物服务;专卖店;专营店|餐饮服务;茶艺馆;茶艺馆","typecode":"061200|050600","biz_type":[],"address":"天马路179号","location":"113.636271,28.135196","tel":"15243692999","distance":[],"biz_ext":{"rating":"3.5","cost":[],"meal_ordering":"0"},"pname":"湖南省","cityname":"长沙市","adname":"浏阳市","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/cc2d503e1f9e23abe5700836c8a5be3a","title":[],"provider":[]},{"url":"http://store.is.autonavi.com/showpic/94cd4fac38bf90eaa69e6c750d664229","title":[],"provider":[]},{"url":"http://store.is.autonavi.com/showpic/1760ef2ef561f247f18b54834d2efa30","title":[],"provider":[]}]},{"id":"B02DB05H8L","parent":[],"childtype":[],"name":"昌盛酒家(铜官镇店)","type":"餐饮服务;中餐厅;中餐厅","typecode":"050100","biz_type":"diner","address":"铜官镇铜官窑品陶轩西北50米","location":"112.809358,28.454926","tel":[],"distance":[],"biz_ext":{"rating":"5.0","cost":"54.00","meal_ordering":"0"},"pname":"湖南省","cityname":"长沙市","adname":"望城区","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/21b8cfc38064055972d058fa6ae15312","title":[],"provider":[]},{"url":"http://store.is.autonavi.com/showpic/a59a9fbc79054d5d145ab7b7990c2a6a","title":"环境","provider":[]},{"url":"http://store.is.autonavi.com/showpic/e2e4dc283db909f68db28a201368ca92","title":"环境","provider":[]}]},{"id":"B0FFF4RG51","parent":[],"childtype":[],"name":"全家园大酒店","type":"住宿服务;宾馆酒店;宾馆酒店|餐饮服务;中餐厅;中餐厅","typecode":"100100|050100","biz_type":"hotel","address":"银杉路229号","location":"112.951818,28.231629","tel":"0731-89807898;0731-88779777","distance":[],"biz_ext":{"rating":"4.5","cost":[],"hotel_ordering":"1","meal_ordering":"0","star":[],"lowest_price":"277.00"},"pname":"湖南省","cityname":"长沙市","adname":"岳麓区","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/125535ae1e5f8c9550909ee1808bac00","title":"外观","provider":[]},{"url":"http://store.is.autonavi.com/showpic/218b545fc1dc78a4a4dc68c9886a78af","title":"内景/公共区域","provider":[]},{"url":"http://store.is.autonavi.com/showpic/c4309ab91749a975aa605ec7db791331","title":"休闲房","provider":[]}]},{"id":"B02DB0UGJB","parent":[],"childtype":[],"name":"乐天茶馆","type":"餐饮服务;茶艺馆;茶艺馆","typecode":"050600","biz_type":"diner","address":"芙蓉北路一段86号华江乐天花亭114号","location":"112.976408,28.280925","tel":[],"distance":[],"biz_ext":{"rating":"4.0","cost":[],"meal_ordering":"0"},"pname":"湖南省","cityname":"长沙市","adname":"开福区","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/d044ff2dd8020a47f4ecc4e7707b6584","title":[],"provider":[]}]},{"id":"B0FFGYO7SX","parent":"B02DB06940","childtype":"202","name":"红馆汇港式茶餐厅(梦泽园店)","type":"餐饮服务;快餐厅;茶餐厅","typecode":"050305","biz_type":"diner","address":"晚报大道63梦泽园商务楼","location":"113.008491,28.207167","tel":"0731-84373377","distance":[],"biz_ext":{"rating":"4.5","cost":"75.00","meal_ordering":"0"},"pname":"湖南省","cityname":"长沙市","adname":"芙蓉区","importance":[],"shopid":[],"shopinfo":"0","poiweight":[],"photos":[{"url":"http://store.is.autonavi.com/showpic/c4f73ef03243253e1 ...

# %% [markdown]
# ### 获取数据

# %%
result = json.loads(res.text)
pprint.pprint(result)
# Out:
# {'count': '893',
#  'info': 'OK',
#  'infocode': '10000',
#  'pois': [{'address': '中岳村浏东公路',
#            'adname': '浏阳市',
#            'biz_ext': {'cost': [], 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFGA6OV1',
#            'importance': [],
#            'location': '113.991255,28.459114',
#            'name': '唐老鸭农庄',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/6bc2efbea43d80030f2e535dc40ccad1'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/e5f0100a7adf360fdb808f6fb4f355ff'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/83fd785681f634fb7836d65cab2ef420'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '18874731138',
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': '天马路179号',
#            'adname': '浏阳市',
#            'biz_ext': {'cost': [], 'meal_ordering': '0', 'rating': '3.5'},
#            'biz_type': [],
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0TUOP',
#            'importance': [],
#            'location': '113.636271,28.135196',
#            'name': '七碗茶(状元洲路)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/cc2d503e1f9e23abe5700836c8a5be3a'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/94cd4fac38bf90eaa69e6c750d664229'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/1760ef2ef561f247f18b54834d2efa30'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '15243692999',
#            'type': '购物服务;专卖店;专营店|餐饮服务;茶艺馆;茶艺馆',
#            'typecode': '061200|050600'},
#           {'address': '铜官镇铜官窑品陶轩西北50米',
#            'adname': '望城区',
#            'biz_ext': {'cost': '54.00', 'meal_ordering': '0', 'rating': '5.0'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB05H8L',
#            'importance': [],
#            'location': '112.809358,28.454926',
#            'name': '昌盛酒家(铜官镇店)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/21b8cfc38064055972d058fa6ae15312'},
#                       {'provider': [],
#                        'title': '环境',
#                        'url': 'http://store.is.autonavi.com/showpic/a59a9fbc79054d5d145ab7b7990c2a6a'},
#                       {'provider': [],
#                        'title': '环境',
#                        'url': 'http://store.is.autonavi.com/showpic/e2e4dc283db909f68db28a201368ca92'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': [],
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': '银杉路229号',
#            'adname': '岳麓区',
#            'biz_ext': {'cost': [],
#                        'hotel_ordering': '1',
#                        'lowest_price': '277.00',
#                        'meal_ordering': '0',
#                        'rating': '4.5',
#                        'star': []},
#            'biz_type': 'hotel',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFF4RG51',
#            'importance': [],
#            'location': '112.951818,28.231629',
#            'name': '全家园大酒店',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': '外观',
#                        'url': 'http://store.is.autonavi.com/showpic/125535ae1e5f8c9550909ee1808bac00'},
#                       {'provider': [],
#                        'title': '内景/公共区域',
#                        'url': 'http://store.is.autonavi.com/showpic/218b545fc1dc78a4a4dc68c9886a78af'},
#                       {'provider': [],
#                        'title': '休闲房',
#                        'url': 'http://store.is.autonavi.com/showpic/c4309ab91749a975aa605ec7db791331'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-89807898;0731-88779777',
#            'type': '住宿服务;宾馆酒店;宾馆酒店|餐饮服务;中餐厅;中餐厅',
#            'typecode': '100100|050100'},
#           {'address': '芙蓉北路一段86号华江乐天花亭114号',
#            'adname': '开福区',
#            'biz_ext': {'cost': [], 'meal_ordering': '0', 'rating': '4.0'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0UGJB',
#            'importance': [],
#            'location': '112.976408,28.280925',
#            'name': '乐天茶馆',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/d044ff2dd8020a47f4ecc4e7707b6584'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': [],
#            'type': '餐饮服务;茶艺馆;茶艺馆',
#            'typecode': '050600'},
#           {'address': '晚报大道63梦泽园商务楼',
#            'adname': '芙蓉区',
#            'biz_ext': {'cost': '75.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': '202',
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFGYO7SX',
#            'importance': [],
#            'location': '113.008491,28.207167',
#            'name': '红馆汇港式茶餐厅(梦泽园店)',
#            'parent': 'B02DB06940',
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/c4f73ef03243253e19b63c00d91a83ae'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/2cb22b894e536f16d217eb7b4cfddb9e'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/22e67e82b62d8f47bf42a44a4f6a58d8'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-84373377',
#            'type': '餐饮服务;快餐厅;茶餐厅',
#            'typecode': '050305'},
#           {'address': '润泽园小区C-12栋2层',
#            'adname': '岳麓区',
#            'biz_ext': {'cost': '51.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFF5ZSBZ',
#            'importance': [],
#            'location': '112.927069,28.213890',
#            'name': '醉东北(谷丰南路)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/900177c0a896ee18e639511fe68f709c'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/07efb217df4a63e9686e94c5bfd88740'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/fa0ec4b2ee4cda5773a54d2f15b948bd'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-89831237',
#            'type': '餐饮服务;中餐厅;东北菜',
#            'typecode': '050113'},
#           {'address': '淮东中路26-2',
#            'adname': '浏阳市',
#            'biz_ext': {'cost': '27.00', 'meal_ordering': '0', 'rating': '4.3'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB05SGH',
#            'importance': [],
#            'location': '113.640091,28.147486',
#            'name': '新村酒楼(淮东中路)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/f9a4a396376e54e92e835944cefd4205'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-83661786;13874933729',
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': '迎宾路238号',
#            'adname': '芙蓉区',
#            'biz_ext': {'cost': '233.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': '3',
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB04D3H',
#            'importance': [],
#            'location': '112.992716,28.202269',
#            'name': '南景饭店(迎宾路店)',
#            'parent': 'B02DB04OXC',
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/5edf8a3797f1e70a68337c3e08c344fa'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/8171deeb67037595de5a8ac2487e0b8e'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/6142a5a38f745947bf5bb53c3c271a83'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-84666798;0731-84666799',
#            'type': '餐饮服务;中餐厅;综合酒楼',
#            'typecode': '050101'},
#           {'address': '曙光中路恒丰佳星园A座1705',
#            'adname': '雨花区',
#            'biz_ext': {'cost': '53.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': '202',
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFGO5TM8',
#            'importance': [],
#            'location': '113.000631,28.175756',
#            'name': '一块美味',
#            'parent': 'B0FFGAK12G',
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/b33f64b614b11aec9e193d790e74a3a2'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/cd806d5c355cd396863744cd075ebce0'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/ee3b968b4f91bdee98228b2e1bcdb994'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '17708475360;17352865860',
#            'type': '餐饮服务;糕饼店;糕饼店',
#            'typecode': '050800'},
#           {'address': '农大长农路6栋13号东湖小区六栋',
#            'adname': '芙蓉区',
#            'biz_ext': {'cost': '20.00', 'meal_ordering': '0', 'rating': '4.9'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFFHBQVH',
#            'importance': [],
#            'location': '113.085638,28.186461',
#            'name': '韩国石锅拌饭年糕辛拉面(湖南农大店)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/b4fdc8d12ab81932a1f25fd9d455a3d9'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/79881f25a7c33fd6c9af114bea6c2a66'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/494dffae6aafe5e72adb52e929d8b06a'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '18273328457',
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': 'G0401绕城高速(黑石铺大桥北侧)',
#            'adname': '天心区',
#            'biz_ext': {'cost': '97.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0VTZ0',
#            'importance': [],
#            'location': '112.950239,28.097658',
#            'name': '天怡·临江鱼馆',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/92d2e31ae68357c78fb716c66ee09f12'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/9d6cd129634b699d2ade69fe14fa589e'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/130c2f65a447d2871d6441731a0de5a1'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-84149822;0731-85049822',
#            'type': '餐饮服务;中餐厅;海鲜酒楼',
#            'typecode': '050119'},
#           {'address': '裕南街82号',
#            'adname': '天心区',
#            'biz_ext': {'cost': '66.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFGB0DZQ',
#            'importance': [],
#            'location': '112.972414,28.173152',
#            'name': '盟重烧烤店',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/0b7fade08a8ebd5a95d9307188cf1fcc'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/b98ea1326c1755beb9320bdf1dc89087'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/68fa349809887b83b83d66ed1dc40d26'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-89677177;15116157760',
#            'type': '餐饮服务;中餐厅;特色/地方风味餐厅',
#            'typecode': '050118'},
#           {'address': '人民中路411号曙光社区01栋',
#            'adname': '芙蓉区',
#            'biz_ext': {'cost': '57.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFG8CDID',
#            'importance': [],
#            'location': '113.003135,28.185638',
#            'name': '离岛咖啡馆',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/ceaad4bf8f7f7055ea697b3987908340'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/de17bf2f773e8702d7795e92d2c5889b'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/4b24bc860aec861d2745699f1061eb9e'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-85222757',
#            'type': '餐饮服务;咖啡厅;咖啡厅',
#            'typecode': '050500'},
#           {'address': '雨花亭凯德广场沃尔玛斜对面阳光小镇1幢3层302',
#            'adname': '雨花区',
#            'biz_ext': {'cost': '85.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFG39IHY',
#            'importance': [],
#            'location': '112.993867,28.155744',
#            'name': '麺咖餐厅(雨花亭店)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/bcbd8ff62b324f473f30af6b6a2d9239'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/53f3663d9454046e6f13ab460ba01d6c'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/ecef637ce8c607ceb7b6126e2aa5fb83'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-85195838;18182103863',
#            'type': '餐饮服务;甜品店;甜品店',
#            'typecode': '050900'},
#           {'address': '梅溪湖加油站南桃花岭天桥西侧200米',
#            'adname': '岳麓区',
#            'biz_ext': {'cost': '100.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B0FFFS4DLW',
#            'importance': [],
#            'location': '112.919126,28.183224',
#            'name': '天怡梅溪湖鱼馆',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/76791f72b927350c296e6b27b0292192'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/aba195e80bac9339c2c47152cf816ddb'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/8eab465dc2c9004551186281427c9247'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-89922877;0731-89922677',
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': '龟山路东栋安置小区',
#            'adname': '芙蓉区',
#            'biz_ext': {'cost': [], 'meal_ordering': '0', 'rating': '5.0'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0XJ7Z',
#            'importance': [],
#            'location': '113.060063,28.196733',
#            'name': '铁胖子土菜馆',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/03d73d0579a4338ba229a1d5f8ee30e2'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/19a26094a9427d23cd425afd58654eab'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '13908453316',
#            'type': '餐饮服务;中餐厅;中餐厅',
#            'typecode': '050100'},
#           {'address': '山月路',
#            'adname': '开福区',
#            'biz_ext': {'cost': '64.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0XJ7U',
#            'importance': [],
#            'location': '113.034238,28.249717',
#            'name': '广殿渔村',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/eed24bd27d1214851fe9d5bd99c0a23f'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/0443eaa1c067c5a9ae436b573f9f533e'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/4a754f21a473c8c3a85622bd185cecaf'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-84250108',
#            'type': '餐饮服务;中餐厅;海鲜酒楼',
#            'typecode': '050119'},
#           {'address': '万家丽中路天际岭隧道口北东面小道上坡50米(天际岭隧道口)',
#            'adname': '雨花区',
#            'biz_ext': {'cost': '80.00', 'meal_ordering': '0', 'rating': '4.6'},
#            'biz_type': 'diner',
#            'childtype': [],
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0VWJX',
#            'importance': [],
#            'location': '113.041589,28.104684',
#            'name': '三祥庄园(天际岭隧道店)',
#            'parent': [],
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/1b67550583cf0f27fdc3ef59364d7fb4'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/3e1f67e884cb155b16f47f5a4b4a17ab'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/232825212eec5faf172edae835a55ac5'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '18874165668',
#            'type': '餐饮服务;中餐厅;特色/地方风味餐厅',
#            'typecode': '050118'},
#           {'address': '劳动西路375号中杨大厦1-2楼(侯家塘新一佳对面)',
#            'adname': '雨花区',
#            'biz_ext': {'cost': '87.00', 'meal_ordering': '0', 'rating': '4.5'},
#            'biz_type': 'diner',
#            'childtype': '202',
#            'cityname': '长沙市',
#            'distance': [],
#            'id': 'B02DB0TRRF',
#            'importance': [],
#            'location': '112.986692,28.171930',
#            'name': '咖稀穆清真餐厅(劳动路店)',
#            'parent': 'B02DB045PQ',
#            'photos': [{'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/b9f6fb542489a053ae902ca4c7e01438'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/382097d4b0f9d8fd42804f022fa947b3'},
#                       {'provider': [],
#                        'title': [],
#                        'url': 'http://store.is.autonavi.com/showpic/fa95713847937027b2990fca825342d7'}],
#            'pname': '湖南省',
#            'poiweight': [],
#            'shopid': [],
#            'shopinfo': '0',
#            'tel': '0731-85533227',
#            'type': '餐饮服务;中餐厅;清真菜馆',
#            'typecode': '050121'}],
#  'status': '1',
#  'suggestion': {'cities': [], 'keywords': []}}

# %%
count = result['count']
count
# Out:
# '893'

# %%
pois = result['pois']
for poi in pois:
    name = poi['name']
    types = poi['type']
    type1 = types.split(';')[0]
    type2 = types.split(';')[1]
    type3 = types.split(';')[2]
    location = poi['location']
    lon = location.split(',')[0]
    lat = location.split(',')[1]
    print(name,type1,type2,type3,lon,lat)
# Out:
# 唐老鸭农庄 餐饮服务 中餐厅 中餐厅 113.991255 28.459114
# 七碗茶(状元洲路) 购物服务 专卖店 专营店|餐饮服务 113.636271 28.135196
# 昌盛酒家(铜官镇店) 餐饮服务 中餐厅 中餐厅 112.809358 28.454926
# 全家园大酒店 住宿服务 宾馆酒店 宾馆酒店|餐饮服务 112.951818 28.231629
# 乐天茶馆 餐饮服务 茶艺馆 茶艺馆 112.976408 28.280925
# 红馆汇港式茶餐厅(梦泽园店) 餐饮服务 快餐厅 茶餐厅 113.008491 28.207167
# 醉东北(谷丰南路) 餐饮服务 中餐厅 东北菜 112.927069 28.213890
# 新村酒楼(淮东中路) 餐饮服务 中餐厅 中餐厅 113.640091 28.147486
# 南景饭店(迎宾路店) 餐饮服务 中餐厅 综合酒楼 112.992716 28.202269
# 一块美味 餐饮服务 糕饼店 糕饼店 113.000631 28.175756
# 韩国石锅拌饭年糕辛拉面(湖南农大店) 餐饮服务 中餐厅 中餐厅 113.085638 28.186461
# 天怡·临江鱼馆 餐饮服务 中餐厅 海鲜酒楼 112.950239 28.097658
# 盟重烧烤店 餐饮服务 中餐厅 特色/地方风味餐厅 112.972414 28.173152
# 离岛咖啡馆 餐饮服务 咖啡厅 咖啡厅 113.003135 28.185638
# 麺咖餐厅(雨花亭店) 餐饮服务 甜品店 甜品店 112.993867 28.155744
# 天怡梅溪湖鱼馆 餐饮服务 中餐厅 中餐厅 112.919126 28.183224
# 铁胖子土菜馆 餐饮服务 中餐厅 中餐厅 113.060063 28.196733
# 广殿渔村 餐饮服务 中餐厅 海鲜酒楼 113.034238 28.249717
# 三祥庄园(天际岭隧道店) 餐饮服务 中餐厅 特色/地方风味餐厅 113.041589 28.104684
# 咖稀穆清真餐厅(劳动路店) 餐饮服务 中餐厅 清真菜馆 112.986692 28.171930

# %% [markdown]
# ### 餐饮数据爬取

# %%
import requests
import json
import csv

# %%
fp = open('poi.csv','a+',newline='',encoding='utf-8')
writer = csv.writer(fp)
writer.writerow(['name','typ1','typ2','typ3','lon','lat'])

urls = ['https://restapi.amap.com/v3/place/text?types=050000&city=长沙&offset=20&page={}&key=这是你的key'.format(str(i)) for i in range(1,100)]

for url in urls:
    res = requests.get(url)

    result = json.loads(res.text)
    count = result['count']
    if count == '0':
        break
    pois = result['pois']
    for poi in pois:
        name = poi['name']
        types = poi['type']
        type1 = types.split(';')[0]
        type2 = types.split(';')[1]
        type3 = types.split(';')[2]
        location = poi['location']
        lon = location.split(',')[0]
        lat = location.split(',')[1]
        print(name,type1,type2,type3,lon,lat)
        writer.writerow([name,type1,type2,type3,lon,lat])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a697e9e2b7f0> in <module>
#       9
#      10     result = json.loads(res.text)
# ---> 11     count = result['count']
#      12     if count == '0':
#      13         break
#
# KeyError: 'count'
